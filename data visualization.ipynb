# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
file_path = r'D:\data visualization\Book1.csv'
ch = pd.read_csv(file_path)
print(ch)
# Out:
#                                                  Book  \
# 0                The Lion, the Witch and the Wardrobe
# 1                         She: A History of Adventure
# 2                                   The Da Vinci Code
# 3             Harry Potter and the Chamber of Secrets
# 4                              The Catcher in the Rye
# 5            Harry Potter and the Prisoner of Azkaban
# 6                 Harry Potter and the Goblet of Fire
# 7               Harry Potter and the Order of Phoenix
# 8              Harry Potter and the Half-Blood Prince
# 9                Harry Potter and the Deathly Hallows
# 10                      The Bridges of Madison County
# 11  One Hundred Years of Solitude (Cien años de so...
# 12                                             Lolita
# 13                                              Heidi
# 14       The Common Sense Book of Baby and Child Care
# 15                               Anne of Green Gables
# ...

# %%
ch.head()
# Out:
#                                       Book         Author(s)  \
# 0     The Lion, the Witch and the Wardrobe        C.S. Lewis
# 1              She: A History of Adventure  H. Rider Haggard
# 2                        The Da Vinci Code         Dan Brown
# 3  Harry Potter and the Chamber of Secrets     J. K. Rowling
# 4                   The Catcher in the Rye    J. D. Salinger
#
#   Original language  First published Approximate sales  \
# 0           English             1950    85 million[35]
# 1           English             1887    83 million[36]
# 2           English             2003    80 million[37]
# 3           English             1998    77 million[38]
# 4           English             1951    65 million[39]
#
#                          Genre
# 0  Fantasy, children's fiction
# 1                    Adventure
# 2             Mystery thriller
# 3  Fantasy, children's fiction
# 4                Coming-of-age

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Book               24 non-null     object
#  1   Author(s)          24 non-null     object
#  2   Original language  24 non-null     object
#  3   First published    24 non-null     int64
#  4   Approximate sales  24 non-null     object
#  5   Genre              24 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ KB

# %%
sns.scatterplot(x='Book',y='First published',data=ch)
# Out:
# <Axes: xlabel='Book', ylabel='First published'>

# %%
sns.lineplot(x='Book',y='First published',data=ch)
# Out:
# <Axes: xlabel='Book', ylabel='First published'>

# %%
sns.violinplot(x='Book',y='First published',data=ch)
# Out:
# <Axes: xlabel='Book', ylabel='First published'>

# %%
sns.barplot(ch['First published'])
# Out:
# <Axes: ylabel='First published'>

# %%
sns.stripplot(x='Original language',y='First published',data=ch)
# Out:
# <Axes: xlabel='Original language', ylabel='First published'>
